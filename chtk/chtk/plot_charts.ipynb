# %%
from pathlib import Path
from chtk import Song

# chart path
chart_path = Path.cwd().parent / 'tests' / 'data' / 'song_0'

song = Song(chart_path)
song.fill_notes()
song.fill_audio()
song.fill_spectrogram()

print(song.spectrogram.shape)
print(song.notes.shape)

song.plot(start=400)

print(song.notes[-1])
# Out:
# 2: c:\Users\Bizon\Documents\GitHub\chtk\chtk\chtk
# (512, 8160)
# (7838,)
# 188

# %%
from chtk import SongDataset
from pathlib import Path

track_pack_path = Path.cwd().parent / 'tests' / 'data' / 'track_pack_simple_structure'
ds = SongDataset(directory = track_pack_path)

ds.df.head()
# Out:
#                                            directory                     name  \
# 0  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...  Guitar Demonstration #2
# 1  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...      Race Into the Light
#
#                                               config chart_format  \
# 0  {'album': 'Young Guitar: Syu 100% BOOK', 'albu...       .chart
# 1  {'album': 'Eye of the Hurricane', 'album_track...       .chart
#
#                                           chart_file  \
# 0  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...
# 1  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...
#
#                                          config_file  \
# 0  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...
# 1  c:\Users\Bizon\Documents\GitHub\chtk\chtk\test...
#
#                                          audio_files  \
# 0  [c:\Users\Bizon\Documents\GitHub\chtk\chtk\tes...
# 1  [c:\Users\Bizon\Documents\GitHub\chtk\chtk\tes...
#
# ...
